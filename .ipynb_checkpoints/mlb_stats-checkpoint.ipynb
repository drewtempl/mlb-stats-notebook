# %% [markdown]
# # MLB Stats API Demo
#
# Using the [python-mlb-statsapi](https://github.com/zero-sum-seattle/python-mlb-statsapi) library to access MLB data.
#
# Install with:
# ```
# pip install python-mlb-statsapi
# ```

# %%
import mlbstatsapi
import pandas as pd

mlb = mlbstatsapi.Mlb()

# %% [markdown]
# ## 1. All MLB Teams (sport_id=1)

# %%
# sport_id=1 is Major League Baseball
mlb_teams = mlb.get_teams(sport_id=1)

print(f"Total MLB teams: {len(mlb_teams)}\n")

mlb_teams_data = [
    {
        "id": team.id,
        "name": team.name,
        "abbreviation": team.abbreviation,
        "league": team.league.name if team.league else None,
        "division": team.division.name if team.division else None,
        "venue": team.venue.name if team.venue else None,
        "location": team.location_name,
    }
    for team in mlb_teams
]

df_mlb = pd.DataFrame(mlb_teams_data).sort_values("name").reset_index(drop=True)
df_mlb
# Out:
# Total MLB teams: 30
#      id                   name abbreviation           league  \
# 0   109   Arizona Diamondbacks           AZ  National League
# 1   133              Athletics          ATH  American League
# 2   144         Atlanta Braves          ATL  National League
# 3   110      Baltimore Orioles          BAL  American League
# 4   111         Boston Red Sox          BOS  American League
# 5   112           Chicago Cubs          CHC  National League
# 6   145      Chicago White Sox          CWS  American League
# 7   113        Cincinnati Reds          CIN  National League
# 8   114    Cleveland Guardians          CLE  American League
# 9   115       Colorado Rockies          COL  National League
# 10  116         Detroit Tigers          DET  American League
# 11  117         Houston Astros          HOU  American League
# 12  118     Kansas City Royals           KC  American League
# 13  108     Los Angeles Angels          LAA  American League
# 14  119    Los Angeles Dodgers          LAD  National League
# 15  146          Miami Marlins          MIA  National League
# 16  158      Milwaukee Brewers          MIL  National League
# 17  142        Minnesota Twins          MIN  American League
# 18  121          New York Mets          NYM  National League
# 19  147       New York Yankees          NYY  American League
# 20  143  Philadelphia Phillies          PHI  National League
# 21  134     Pittsburgh Pirates          PIT  National League
# 22  135       San Diego Padres           SD  National League
# 23  137   San Francisco Giants           SF  National League
# 24  136       Seattle Mariners          SEA  American League
# 25  138    St. Louis Cardinals          STL  National League
# 26  139         Tampa Bay Rays           TB  American League
# 27  140          Texas Rangers          TEX  American League
# 28  141      Toronto Blue Jays          TOR  American League
# 29  120   Washington Nationals          WSH  National League
#
#                    division                        venue        location
# 0      National League West                  Chase Field         Phoenix
# 1      American League West           Sutter Health Park      Sacramento
# 2      National League East                  Truist Park         Atlanta
# 3      American League East  Oriole Park at Camden Yards       Baltimore
# 4      American League East                  Fenway Park          Boston
# 5   National League Central                Wrigley Field         Chicago
# 6   American League Central                   Rate Field         Chicago
# 7   National League Central     Great American Ball Park      Cincinnati
# 8   American League Central            Progressive Field       Cleveland
# 9      National League West                  Coors Field          Denver
# 10  American League Central                Comerica Park         Detroit
# 11     American League West                  Daikin Park         Houston
# 12  American League Central             Kauffman Stadium     Kansas City
# 13     American League West                Angel Stadium         Anaheim
# 14     National League West               Dodger Stadium     Los Angeles
# 15     National League East               loanDepot park           Miami
# 16  National League Central        American Family Field       Milwaukee
# 17  American League Central                 Target Field     Minneapolis
# 18     National League East                   Citi Field        Flushing
# 19     American League East               Yankee Stadium           Bronx
# 20     National League East           Citizens Bank Park    Philadelphia
# 21  National League Central                     PNC Park      Pittsburgh
# 22     National League West                   Petco Park       San Diego
# 23     National League West                  Oracle Park   San Francisco
# 24     American League West                T-Mobile Park         Seattle
# 25  National League Central                Busch Stadium       St. Louis
# 26     American League East              Tropicana Field  St. Petersburg
# 27     American League West             Globe Life Field       Arlington
# 28     American League East                Rogers Centre         Toronto
# 29     National League East               Nationals Park      Washington

# %% [markdown]
# ## 2. Available Sports / Leagues
#
# Use `get_sports()` to discover sport IDs for minor leagues.

# %%
sports = mlb.get_sports()

sports_data = [
    {"id": sport.id, "name": sport.name, "abbreviation": getattr(sport, 'abbreviation', None)}
    for sport in sports
]

df_sports = pd.DataFrame(sports_data).sort_values("id").reset_index(drop=True)
df_sports
# Out:
#       id                                   name abbreviation
# 0      1                  Major League Baseball          MLB
# 1     11                               Triple-A          AAA
# 2     12                               Double-A           AA
# 3     13                                 High-A           A+
# 4     14                               Single-A            A
# 5     16                                 Rookie          ROK
# 6     17                         Winter Leagues          WIN
# 7     21                  Minor League Baseball       Minors
# 8     22                       College Baseball      College
# 9     23                    Independent Leagues          IND
# 10    31           Nippon Professional Baseball          NPB
# 11    32           Korean Baseball Organization          KOR
# 12    51                 International Baseball          INT
# 13    61                  Negro League Baseball          NLB
# 14   509           International Baseball (18U)          18U
# 15   510  International Baseball (16 and under)          16U
# 16   576          Women's Professional Softball          WPS
# 17   586                   High School Baseball         H.S.
# 18  6005       International Baseball (amateur)          AME

# %% [markdown]
# ## 3. All Minor League Teams
#
# Minor league sport IDs:
# - `11` = Triple-A
# - `12` = Double-A
# - `13` = High-A
# - `14` = Single-A
# - `16` = Rookie
#
# We fetch teams for each level and combine them.

# %%
MINOR_LEAGUE_SPORT_IDS = {
    11: "Triple-A",
    # 12: "Double-A",
    # 13: "High-A",
    # 14: "Single-A",
    # 16: "Rookie",
}

minor_league_rows = []

for sport_id, level_name in MINOR_LEAGUE_SPORT_IDS.items():
    teams = mlb.get_teams(sport_id=sport_id)
    print(f"{level_name} (sport_id={sport_id}): {len(teams)} teams")
    for team in teams:
        minor_league_rows.append({
            "level": level_name,
            "sport_id": sport_id,
            "id": team.id,
            "name": team.name,
            "abbreviation": team.abbreviation,
            "league": team.league.name if team.league else None,
            "location": team.location_name,
            "venue": team.venue.name if team.venue else None,
        })

df_minor = pd.DataFrame(minor_league_rows).sort_values(["sport_id", "name"]).reset_index(drop=True)
print(f"\nTotal minor league teams: {len(df_minor)}")
df_minor
# Out:
# Triple-A (sport_id=11): 30 teams
#
# Total minor league teams: 30
#        level  sport_id    id                              name abbreviation  \
# 0   Triple-A        11   342              Albuquerque Isotopes          ABQ
# 1   Triple-A        11   422                    Buffalo Bisons          BUF
# 2   Triple-A        11   494                 Charlotte Knights          CLT
# 3   Triple-A        11   445                 Columbus Clippers          COL
# 4   Triple-A        11   234                      Durham Bulls          DUR
# 5   Triple-A        11  4904                El Paso Chihuahuas          ELP
# 6   Triple-A        11   431                 Gwinnett Stripers          GWN
# 7   Triple-A        11   484              Indianapolis Indians          IND
# 8   Triple-A        11   451                         Iowa Cubs          IOW
# 9   Triple-A        11   564         Jacksonville Jumbo Shrimp          JAX
# 10  Triple-A        11   400                Las Vegas Aviators           LV
# 11  Triple-A        11  1410            Lehigh Valley IronPigs          LHV
# 12  Triple-A        11   416                   Louisville Bats          LOU
# 13  Triple-A        11   235                  Memphis Redbirds          MEM
# 14  Triple-A        11   556                  Nashville Sounds          NAS
# 15  Triple-A        11   568                     Norfolk Tides          NOR
# 16  Triple-A        11   238              Oklahoma City Comets          OKC
# 17  Triple-A        11   541               Omaha Storm Chasers          OMA
# 18  Triple-A        11  2310                         Reno Aces          RNO
# 19  Triple-A        11   534               Rochester Red Wings          ROC
# 20  Triple-A        11   102                Round Rock Express           RR
# 21  Triple-A        11   105             Sacramento River Cats          SAC
# 22  Triple-A        11   561                    Salt Lake Bees           SL
# 23  Triple-A        11   531  Scranton/Wilkes-Barre RailRiders          SWB
# 24  Triple-A        11  1960                   St. Paul Saints          STP
# 25  Triple-A        11  5434          Sugar Land Space Cowboys          SUG
# 26  Triple-A        11   552                     Syracuse Mets          SYR
# 27  Triple-A        11   529                   Tacoma Rainiers          TAC
# 28  Triple-A        11   512                   Toledo Mud Hens          TOL
# 29  Triple-A        11   533                 Worcester Red Sox          WOR
#
#                   league       location                                 venue
# 0   Pacific Coast League    Albuquerque                         Isotopes Park
# 1   International League        Buffalo                          Sahlen Field
# 2   International League      Charlotte                          Truist Field
# 3   International League       Columbus                       Huntington Park
# 4   International League         Durham            Durham Bulls Athletic Park
# 5   Pacific Coast League        El Paso             Southwest University Park
# 6   International League  Lawrenceville                        Gwinnett Field
# 7   International League   Indianapolis                         Victory Field
# 8   International League     Des Moines                        Principal Park
# 9   International League   Jacksonville                       Vystar Ballpark
# 10  Pacific Coast League      Las Vegas                    Las Vegas Ballpark
# 11  International League      Allentown                        Coca-Cola Park
# 12  International League     Louisville              Louisville Slugger Field
# 13  International League        Memphis                         AutoZone Park
# 14  International League      Nashville                    First Horizon Park
# 15  International League        Norfolk                           Harbor Park
# 16  Pacific Coast League  Oklahoma City          Chickasaw Bricktown Ballpark
# 17  International League      Papillion                           Werner Park
# 18  Pacific Coast League           Reno                  Greater Nevada Field
# 19  International League      Rochester                      Innovative Field
# 20  Pacific Coast League     Round Rock                          Dell Diamond
# 21  Pacific Coast League     Sacramento                    Sutter Health Park
# 22  Pacific Coast League   South Jordan  The Ballpark at America First Square
# 23  International League         Moosic                             PNC Field
# 24  International League       St. Paul                             CHS Field
# 25  Pacific Coast League     Sugar Land                   Constellation Field
# 26  International League       Syracuse                      NBT Bank Stadium
# 27  Pacific Coast League         Tacoma                        Cheney Stadium
# 28  International League         Toledo                     Fifth Third Field
# 29  International League      Worcester                            Polar Park

# %% [markdown]
# ## 4. Summary

# %% [markdown]
# ## 5. Active MLB Players

# %%
players = mlb.get_people(sport_id=1)

players_data = [
    {
        "id": p.id,
        "full_name": p.full_name,
        "first_name": p.first_name,
        "last_name": p.last_name,
        "jersey_number": getattr(p, "primary_number", None),
        "position": p.primary_position.abbreviation if p.primary_position else None,
        "position_name": p.primary_position.name if p.primary_position else None,
        "team": p.current_team.name if p.current_team else None,
        "bat_side": p.bat_side.description if p.bat_side else None,
        "pitch_hand": p.pitch_hand.description if p.pitch_hand else None,
        "birth_date": getattr(p, "birth_date", None),
        "active": getattr(p, "active", None),
    }
    for p in players
]

df_players = pd.DataFrame(players_data).sort_values(["team", "last_name"]).reset_index(drop=True)
print(f"Total players: {len(df_players)}")
df_players
# Out:
# Total players: 1471
#           id        full_name first_name last_name jersey_number position  \
# 0     506702       Sandy León      Sandy      León             9        C
# 1     671096    Andrew Abbott     Andrew    Abbott            41        P
# 2     690953        Mick Abel     McLean      Abel            40        P
# 3     691769     Philip Abner     Philip     Abner            50        P
# 4     682928        CJ Abrams       Paul    Abrams             5       SS
# ...      ...              ...        ...       ...           ...      ...
# 1466  676604      Tyler Zuber      Tyler     Zuber            53        P
# 1467  691172   Yosver Zulueta     Yosver   Zulueta            67        P
# 1468  518595  Travis d'Arnaud     Travis  d'Arnaud            25        C
# 1469  676969    Brett de Geus      Brett   de Geus            74        P
# 1470  594798     Jacob deGrom      Jacob    deGrom            48        P
#
#      position_name            team bat_side pitch_hand  birth_date  active
# 0          Catcher  Atlanta Braves   Switch      Right  1989-03-13    True
# 1          Pitcher             NaN     Left       Left  1999-06-01    True
# 2          Pitcher             NaN    Right      Right  2001-08-18    True
# 3          Pitcher             NaN     Left       Left  2002-05-05    True
# 4        Shortstop             NaN     Left      Right  2000-10-03    True
# ...            ...             ...      ...        ...         ...     ...
# 1466       Pitcher             NaN    Right      Right  1995-06-16    True
# 1467       Pitcher             NaN    Right      Right  1998-01-23    True
# 1468       Catcher             NaN    Right      Right  1989-02-10    True
# 1469       Pitcher             NaN    Right      Right  1997-11-04    True
# 1470       Pitcher             NaN     Left      Right  1988-06-19    True
#
# [1471 rows x 12 columns]

# %% [markdown]
# ## 6. Team Roster

# %%
ROSTER_TEAM_ID = 139        # e.g. 147 = Yankees; see df_mlb for IDs
ROSTER_TYPE   = "fullRoster"    # 40Man | fullSeason | fullRoster | active | etc.

roster = mlb.get_team_roster(team_id=ROSTER_TEAM_ID, rosterType=ROSTER_TYPE)

roster_data = [
    {
        "id": p.id,
        "full_name": p.full_name,
        "jersey_number": p.jersey_number,
        "position": p.primary_position.abbreviation if p.primary_position else None,
        "position_name": p.primary_position.name if p.primary_position else None,
        "status": p.status.description if p.status else None,
        "bat_side": p.bat_side.description if p.bat_side else None,
        "pitch_hand": p.pitch_hand.description if p.pitch_hand else None,
        "note": getattr(p, "note", None),
    }
    for p in roster
]

df_roster = pd.DataFrame(roster_data).sort_values("position").reset_index(drop=True)
print(f"Team ID {ROSTER_TEAM_ID} · {ROSTER_TYPE} roster: {len(df_roster)} players")
df_roster
# Out:
# Team ID 139 · fullRoster roster: 243 players
#          id        full_name jersey_number position position_name  status  \
# 0    666018  Jonathan Aranda             8       1B    First Base  Active
# 1    687545  Blake Robertson            31       1B    First Base  Active
# 2    700178       Ryan McCoy                     1B    First Base  Active
# 3    803067     Brady Marget                     1B    First Base  Active
# 4    650490       Yandy Díaz             2       1B    First Base  Active
# ..      ...              ...           ...      ...           ...     ...
# 238  800440  Narciso Polanco             8       SS     Shortstop  Active
# 239  686540        Owen Cobb             7       SS     Shortstop  Active
# 240  692150    Émilien Pitre             7       SS     Shortstop  Active
# 241  689216    Jalen Battles            12       SS     Shortstop  Active
# 242  813922       Jack Lines            17       SS     Shortstop  Active
#
#     bat_side pitch_hand  note
# 0       None       None  None
# 1       None       None  None
# 2       None       None  None
# 3       None       None  None
# 4       None       None  None
# ..       ...        ...   ...
# 238     None       None  None
# 239     None       None  None
# 240     None       None  None
# 241     None       None  None
# 242     None       None  None
#
# [243 rows x 9 columns]

# %% [markdown]
# ## 7. Schedule

# %%
SCHEDULE_START_DATE = "2026-04-01"
SCHEDULE_END_DATE   = "2026-05-01"
SCHEDULE_TEAM_ID    = 139          # e.g. 147 for Yankees, or None for all teams

schedule = mlb.get_schedule(
    start_date=SCHEDULE_START_DATE,
    end_date=SCHEDULE_END_DATE,
    sport_id=1,
    team_id=SCHEDULE_TEAM_ID,
)

schedule_rows = []
if schedule:
    for day in schedule.dates:
        for game in day.games:
            away = game.teams.away if game.teams else None
            home = game.teams.home if game.teams else None
            schedule_rows.append({
                "game_pk":            game.game_pk,
                "date":               day.date,
                "game_date":          game.game_date,
                "day_night":          getattr(game, "day_night", None),
                "away_team":          away.team.name if away and away.team else None,
                "home_team":          home.team.name if home and home.team else None,
                "away_score":         away.score if away else None,
                "home_score":         home.score if home else None,
                "status":             game.status.detailed_state if game.status else None,
                "venue":              game.venue.name if game.venue else None,
                "series_description": getattr(game, "series_description", None),
                "game_number":        getattr(game, "series_game_number", None),
                "games_in_series":    getattr(game, "games_in_series", None),
            })

df_schedule = pd.DataFrame(schedule_rows)
print(f"Games from {SCHEDULE_START_DATE} to {SCHEDULE_END_DATE}: {len(df_schedule)}")
df_schedule
# Out:
# Games from 2026-04-01 to 2026-05-01: 26
#     game_pk        date             game_date day_night             away_team  \
# 0    823806  2026-04-01  2026-04-01T17:40:00Z       day        Tampa Bay Rays
# 1    823732  2026-04-03  2026-04-03T20:10:00Z       day        Tampa Bay Rays
# 2    823730  2026-04-04  2026-04-04T23:10:00Z     night        Tampa Bay Rays
# 3    823729  2026-04-05  2026-04-05T18:10:00Z       day        Tampa Bay Rays
# 4    823002  2026-04-06  2026-04-06T20:10:00Z       day          Chicago Cubs
# 5    822999  2026-04-07  2026-04-07T22:40:00Z     night          Chicago Cubs
# 6    823000  2026-04-08  2026-04-08T22:40:00Z     night          Chicago Cubs
# 7    822997  2026-04-10  2026-04-10T23:10:00Z     night      New York Yankees
# 8    822996  2026-04-11  2026-04-11T22:10:00Z     night      New York Yankees
# 9    822998  2026-04-12  2026-04-12T17:40:00Z       day      New York Yankees
# 10   824616  2026-04-14  2026-04-14T23:40:00Z     night        Tampa Bay Rays
# 11   824615  2026-04-15  2026-04-15T23:40:00Z     night        Tampa Bay Rays
# 12   824614  2026-04-16  2026-04-16T18:10:00Z       day        Tampa Bay Rays
# 13   823397  2026-04-17  2026-04-17T22:45:00Z     night        Tampa Bay Rays
# 14   823394  2026-04-18  2026-04-18T20:05:00Z       day        Tampa Bay Rays
# 15   823393  2026-04-19  2026-04-19T17:35:00Z       day        Tampa Bay Rays
# 16   822994  2026-04-20  2026-04-20T22:40:00Z     night       Cincinnati Reds
# 17   822995  2026-04-21  2026-04-21T22:40:00Z     night       Cincinnati Reds
# 18   822993  2026-04-22  2026-04-22T17:10:00Z       day       Cincinnati Reds
# 19   822992  2026-04-24  2026-04-24T23:10:00Z     night       Minnesota Twins
# 20   822989  2026-04-25  2026-04-25T20:10:00Z       day       Minnesota Twins
# 21   822991  2026-04-26  2026-04-26T17:40:00Z       day       Minnesota Twins
# 22   824446  2026-04-27  2026-04-27T22:10:00Z     night        Tampa Bay Rays
# 23   824447  2026-04-28  2026-04-28T22:10:00Z     night        Tampa Bay Rays
# 24   824445  2026-04-29  2026-04-29T17:10:00Z       day        Tampa Bay Rays
# 25   822990  2026-05-01  2026-05-01T23:10:00Z     night  San Francisco Giants
#
#               home_team away_score home_score     status  \
# 0     Milwaukee Brewers       None       None  Scheduled
# 1       Minnesota Twins       None       None  Scheduled
# 2       Minnesota Twins       None       None  Scheduled
# 3       Minnesota Twins       None       None  Scheduled
# 4        Tampa Bay Rays       None       None  Scheduled
# 5        Tampa Bay Rays       None       None  Scheduled
# 6        Tampa Bay Rays       None       None  Scheduled
# 7        Tampa Bay Rays       None       None  Scheduled
# 8        Tampa Bay Rays       None       None  Scheduled
# 9        Tampa Bay Rays       None       None  Scheduled
# 10    Chicago White Sox       None       None  Scheduled
# 11    Chicago White Sox       None       None  Scheduled
# 12    Chicago White Sox       None       None  Scheduled
# 13   Pittsburgh Pirates       None       None  Scheduled
# 14   Pittsburgh Pirates       None       None  Scheduled
# 15   Pittsburgh Pirates       None       None  Scheduled
# 16       Tampa Bay Rays       None       None  Scheduled
# 17       Tampa Bay Rays       None       None  Scheduled
# 18       Tampa Bay Rays       None       None  Scheduled
# 19       Tampa Bay Rays       None       None  Scheduled
# 20       Tampa Bay Rays       None       None  Scheduled
# 21       Tampa Bay Rays       None       None  Scheduled
# 22  Cleveland Guardians       None       None  Scheduled
# 23  Cleveland Guardians       None       None  Scheduled
# 24  Cleveland Guardians       None       None  Scheduled
# 25       Tampa Bay Rays       None       None  Scheduled
#
#                     venue series_description  game_number  games_in_series
# 0   American Family Field     Regular Season            3                3
# 1            Target Field     Regular Season            1                3
# 2            Target Field     Regular Season            2                3
# 3            Target Field     Regular Season            3                3
# 4         Tropicana Field     Regular Season            1                3
# 5         Tropicana Field     Regular Season            2                3
# 6         Tropicana Field     Regular Season            3                3
# 7         Tropicana Field     Regular Season            1                3
# 8         Tropicana Field     Regular Season            2                3
# 9         Tropicana Field     Regular Season            3                3
# 10             Rate Field     Regular Season            1                3
# 11             Rate Field     Regular Season            2                3
# 12             Rate Field     Regular Season            3                3
# 13               PNC Park     Regular Season            1                3
# 14               PNC Park     Regular Season            2                3
# 15               PNC Park     Regular Season            3                3
# 16        Tropicana Field     Regular Season            1                3
# 17        Tropicana Field     Regular Season            2                3
# 18        Tropicana Field     Regular Season            3                3
# 19        Tropicana Field     Regular Season            1                3
# 20        Tropicana Field     Regular Season            2                3
# 21        Tropicana Field     Regular Season            3                3
# 22      Progressive Field     Regular Season            1                3
# 23      Progressive Field     Regular Season            2                3
# 24      Progressive Field     Regular Season            3                3
# 25        Tropicana Field     Regular Season            1                3

# %% [markdown]
# ## 8. Game Detail (GUMBO Feed)

# %%
GAME_PK = 776918  # use a game_pk from df_schedule above

game = mlb.get_game(game_id=GAME_PK)

# --- Game summary ---
gd   = game.game_data
ld   = game.live_data
info = gd.game_info if gd else None

away_team = gd.teams.away.name if gd and gd.teams and gd.teams.away else None
home_team = gd.teams.home.name if gd and gd.teams and gd.teams.home else None

summary = {
    "game_pk":          game.game_pk,
    "date":             gd.datetime.official_date if gd and gd.datetime else None,
    "time":             f"{gd.datetime.time} {gd.datetime.ampm}" if gd and gd.datetime else None,
    "status":           gd.status.detailed_state if gd and gd.status else None,
    "away_team":        away_team,
    "home_team":        home_team,
    "venue":            gd.venue.name if gd and gd.venue else None,
    "weather":          f"{gd.weather.temp}°F, {gd.weather.condition}" if gd and gd.weather else None,
    "wind":             gd.weather.wind if gd and gd.weather else None,
    "attendance":       info.attendance if info else None,
    "duration_min":     info.game_duration_minutes if info else None,
    "season":           gd.game.season if gd and gd.game else None,
}

print("=== Game Summary ===")
for k, v in summary.items():
    print(f"  {k:<16} {v}")

# --- Linescore ---
ls = ld.linescore if ld else None
if ls and ls.innings:
    inning_rows = []
    for inn in ls.innings:
        inning_rows.append({
            "inning":      inn.num,
            "away_runs":   getattr(inn.away, "runs",  None) if inn.away else None,
            "away_hits":   getattr(inn.away, "hits",  None) if inn.away else None,
            "away_errors": getattr(inn.away, "errors",None) if inn.away else None,
            "home_runs":   getattr(inn.home, "runs",  None) if inn.home else None,
            "home_hits":   getattr(inn.home, "hits",  None) if inn.home else None,
            "home_errors": getattr(inn.home, "errors",None) if inn.home else None,
        })
    df_linescore = pd.DataFrame(inning_rows)

    # totals row
    totals = pd.DataFrame([{
        "inning":      "TOTAL",
        "away_runs":   getattr(ls.teams.away, "runs",   None) if ls.teams and ls.teams.away else None,
        "away_hits":   getattr(ls.teams.away, "hits",   None) if ls.teams and ls.teams.away else None,
        "away_errors": getattr(ls.teams.away, "errors", None) if ls.teams and ls.teams.away else None,
        "home_runs":   getattr(ls.teams.home, "runs",   None) if ls.teams and ls.teams.home else None,
        "home_hits":   getattr(ls.teams.home, "hits",   None) if ls.teams and ls.teams.home else None,
        "home_errors": getattr(ls.teams.home, "errors", None) if ls.teams and ls.teams.home else None,
    }])
    df_linescore = pd.concat([df_linescore, totals], ignore_index=True)

    print(f"\n=== Linescore  ({away_team} @ {home_team}) ===")
    display(df_linescore)

# --- Decisions ---
decisions = getattr(ld, "decisions", None) if ld else None
if decisions:
    print("=== Decisions ===")
    for role in ("winner", "loser", "save"):
        p = getattr(decisions, role, None)
        if p:
            print(f"  {role.capitalize():<8} {p.full_name}")
# Out:
# === Game Summary ===
#   game_pk          776918
#   date             2025-08-01
#   time             7:35 PM
#   status           Final
#   away_team        Los Angeles Dodgers
#   home_team        Tampa Bay Rays
#   venue            George M. Steinbrenner Field
#   weather          89°F, Partly Cloudy
#   wind             4 mph, L To R
#   attendance       10046
#   duration_min     142
#   season           2025
#
# === Linescore  (Los Angeles Dodgers @ Tampa Bay Rays) ===
#   inning  away_runs  away_hits  away_errors  home_runs  home_hits  home_errors
# 0      1          2          2            0          0          1            0
# 1      2          0          0            0          0          2            0
# 2      3          0          1            0          0          1            0
# 3      4          2          4            0          0          0            0
# 4      5          1          1            0          0          0            0
# 5      6          0          1            1          0          1            0
# 6      7          0          0            0          0          0            0
# 7      8          0          0            0          0          0            0
# 8      9          0          0            0          0          1            0
# 9  TOTAL          5          9            1          0          6            0
# === Decisions ===
#   Winner   Clayton Kershaw
#   Loser    Shane Baz
#   Save     Justin Wrobleski

# %% [markdown]
# ## 9. Transactions

# %%
import requests

TRANSACTION_START_DATE = "2026-01-01"
TRANSACTION_END_DATE   = "2026-02-01"
TRANSACTION_TEAM_ID    = 139   # e.g. 147 for Yankees, or None for all teams
TRANSACTION_PLAYER_ID  = None   # e.g. 592450 for Gerrit Cole, or None for all players

params = {
    "startDate": TRANSACTION_START_DATE,
    "endDate":   TRANSACTION_END_DATE,
}
if TRANSACTION_TEAM_ID:
    params["teamId"] = TRANSACTION_TEAM_ID
if TRANSACTION_PLAYER_ID:
    params["playerId"] = TRANSACTION_PLAYER_ID

resp = requests.get("https://statsapi.mlb.com/api/v1/transactions", params=params)
resp.raise_for_status()
raw = resp.json().get("transactions", [])

transaction_rows = [
    {
        "id":               t.get("id"),
        "date":             t.get("date"),
        "effective_date":   t.get("effectiveDate"),
        "resolution_date":  t.get("resolutionDate"),
        "type_code":        t.get("typeCode"),
        "type_desc":        t.get("typeDesc"),
        "player_id":        t["person"]["id"]       if t.get("person")   else None,
        "player":           t["person"]["fullName"]  if t.get("person")   else None,
        "from_team":        t["fromTeam"]["name"]    if t.get("fromTeam") else None,
        "to_team":          t["toTeam"]["name"]      if t.get("toTeam")   else None,
        "description":      t.get("description"),
    }
    for t in raw
]

df_transactions = pd.DataFrame(transaction_rows).sort_values(["date", "player"]).reset_index(drop=True)
print(f"Transactions from {TRANSACTION_START_DATE} to {TRANSACTION_END_DATE}: {len(df_transactions)}")
df_transactions
# Out:
# {'copyright': 'Copyright 2026 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt', 'transactions': [{'id': 883247, 'person': {'id': 658668, 'fullName': 'Edward Olivares', 'link': '/api/v1/people/658668'}, 'toTeam': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'}, 'date': '2026-01-06', 'effectiveDate': '2026-01-06', 'resolutionDate': '2026-01-06', 'typeCode': 'SC', 'typeDesc': 'Status Change', 'description': 'RF Edward Olivares roster status changed by Tampa Bay Rays.'}, {'id': 880669, 'person': {'id': 658668, 'fullName': 'Edward Olivares', 'link': '/api/v1/people/658668'}, 'toTeam': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'}, 'date': '2026-01-06', 'effectiveDate': '2026-01-06', 'resolutionDate': '2026-01-06', 'typeCode': 'SFA', 'typeDesc': 'Signed as Free Agent', 'description': 'Tampa Bay Rays signed free agent RF Edward Olivares to a minor league contract.'}, {'id': 880169, 'fromTeam': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'}, 'toTeam': {'id': 116, 'name': 'Detroit Tigers', 'link': '/api/v1/teams/116'}, 'date': '2026-01-06', 'effectiveDate': '2026-01-06', 'typeCode': 'TR', 'typeDesc': 'Trade', 'description': 'Detroit Tigers traded RF Justyn-Henry Malloy to Tampa Bay Rays for cash.'}, {'id': 880169, 'person': {'id': 669234, 'fullName': 'Justyn-Henry Malloy', 'link': '/api/v1/people/669234'}, 'fromTeam': {'id': 116, 'name': 'Detroit Tigers', 'link': '/api/v1/teams/116'}, 'toTeam': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'}, 'date': '2026-01-06', 'effectiveDate': '2026-01-06', 'typeCode': 'TR', 'typeDesc': 'Trade', 'description': 'Detroit Tigers traded RF Justyn-Henry Malloy to Tampa Bay Rays for cash.'}, {'id': 880993, 'person': {'id': 686678, 'fullName': 'Chase Solesky', 'link': '/api/v1/people/686678'}, 'toTeam': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'}, 'date': '2026-01-07', 'effectiveDate': '2026-01-07', 'resolutionDate': '2026-01-07', 'typeCode': 'SFA', 'typeDesc': 'Signed as Free Agent', 'description': 'Tampa Bay Rays signed free agent RHP Chase Solesky to a minor league contract.'}, {'id': 883235, 'person': {'id': 686678, 'fullName': 'Chase Solesky', 'link': '/api/v1/people/686678'}, 'toTeam': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'}, 'date': '2026-01-07', 'effectiveDate': '2026-01-07', 'resolutionDate': '2026-01-07', 'typeCode': 'SC', 'typeDesc': 'Status Change', 'description': 'RHP Chase Solesky roster status changed by Tampa Bay Rays.'}, {'id': 880319, 'person': {'id': 691907, 'fullName': 'Tsung-Che Cheng', 'link': '/api/v1/people/691907'}, 'fromTeam': {'id': 134, 'name': 'Pittsburgh Pirates', 'link': '/api/v1/teams/134'}, 'toTeam': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'}, 'date': '2026-01-07', 'effectiveDate': '2026-01-07', 'typeCode': 'CLW', 'typeDesc': 'Claimed Off Waivers', 'description': 'Tampa Bay Rays claimed SS Tsung-Che Cheng off waivers from Pittsburgh Pirates.'}, {'id': 883246, 'person': {'id': 666165, 'fullName': 'Blake Sabol', 'link': '/api/v1/people/666165'}, 'toTeam': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'}, 'date': '2026-01-08', 'effectiveDate': '2026-01-08', 'resolutionDate': '2026-01-08', 'typeCode': 'SC', 'typeDesc': 'Status Change', 'description': 'C Blake Sabol roster status changed by Tampa Bay Rays.'}, {'id': 880722, 'person': {'id': 666165, 'fullName': 'Blake Sabol', 'link': '/api/v1/people/666165'}, 'toTeam': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'}, 'date': '2026-01-08', 'effectiveDate': '2026-01-08', 'resolutionDate': '2026-01-08', 'typeCode': 'SFA', 'typeDesc': 'Signed as Free Agent', 'description': 'Tampa Bay Rays signed free agent C Blake Sabol to a minor league contract.'}, {'id': 884404, 'person': {'id': 657611, 'fullName': 'Cam Hill', 'link': '/api/v1/people/657611'}, ...
# Transactions from 2026-01-01 to 2026-02-01: 50
#         id        date effective_date resolution_date type_code  \
# 0   883247  2026-01-06     2026-01-06      2026-01-06        SC
# 1   880669  2026-01-06     2026-01-06      2026-01-06       SFA
# 2   880169  2026-01-06     2026-01-06             NaN        TR
# 3   880169  2026-01-06     2026-01-06             NaN        TR
# 4   880993  2026-01-07     2026-01-07      2026-01-07       SFA
# 5   883235  2026-01-07     2026-01-07      2026-01-07        SC
# 6   880319  2026-01-07     2026-01-07             NaN       CLW
# 7   883246  2026-01-08     2026-01-08      2026-01-08        SC
# 8   880722  2026-01-08     2026-01-08      2026-01-08       SFA
# 9   884404  2026-01-08     2026-01-08      2026-01-08       SFA
# 10  880703  2026-01-12     2026-01-12             NaN        TR
# 11  880699  2026-01-12     2026-01-12      2026-01-12       NUM
# 12  880703  2026-01-12     2026-01-12             NaN        TR
# 13  880704  2026-01-12     2026-01-12      2026-01-12       DES
# 14  880705  2026-01-12     2026-01-12      2026-01-12       DES
# 15  880703  2026-01-12     2026-01-12             NaN        TR
# 16  881440  2026-01-15     2026-01-15      2026-01-15       SFA
# 17  881393  2026-01-15     2026-01-15      2026-01-15       SFA
# 18  881937  2026-01-15     2026-01-15      2026-01-15       SFA
# 19  881457  2026-01-15     2026-01-15      2026-01-15       SFA
# 20  881941  2026-01-15     2026-01-15      2026-01-15       SFA
# 21  881476  2026-01-15     2026-01-15      2026-01-15       SFA
# 22  881544  2026-01-15     2026-01-15      2026-01-15       SFA
# 23  881570  2026-01-15     2026-01-15      2026-01-15       SFA
# 24  881943  2026-01-15     2026-01-15      2026-01-15       SFA
# 25  881541  2026-01-15     2026-01-15      2026-01-15       SFA
# 26  881590  2026-01-15     2026-01-15      2026-01-15       SFA
# 27  881413  2026-01-16     2026-01-16             NaN        TR
# 28  881413  2026-01-16     2026-01-16             NaN        TR
# 29  881413  2026-01-16     2026-01-16             NaN        TR
# 30  881598  2026-01-16     2026-01-16             NaN       CLW
# 31  881597  2026-01-16     2026-01-16             NaN       CLW
# 32  882969  2026-01-26     2026-01-26      2026-01-26       SFA
# 33  883241  2026-01-26     2026-01-26      2026-01-26        SC
# 34  883237  2026-01-30     2026-01-30      2026-01-30       ASG
# 35  883236  2026-01-30     2026-01-30      2026-01-30       ASG
# 36  883254  2026-01-30     2026-01-30      2026-01-30       ASG
# 37  883231  2026-01-30     2026-01-30      2026-01-30       ASG
# 38  883252  2026-01-30     2026-01-30      2026-01-30       ASG
# 39  883248  2026-01-30     2026-01-30      2026-01-30       ASG
# 40  883245  2026-01-30     2026-01-30      2026-01-30       ASG
# 41  883238  2026-01-30     2026-01-30      2026-01-30       ASG
# 42  883243  2026-01-30     2026-01-30      2026-01-30       ASG
# 43  883240  2026-01-30     2026-01-30      2026-01-30       ASG
# 44  883234  2026-01-30     2026-01-30      2026-01-30       ASG
# 45  883244  2026-01-30     2026-01-30      2026-01-30       ASG
# 46  883253  2026-01-30     2026-01-30      2026-01-30       ASG
# 47  883233  2026-01-30     2026-01-30      2026-01-30       ASG
# 48  883232  2026-01-30     2026-01-30      2026-01-30       ASG
# 49  883251  2026-01-30     2026-01-30      2026-01-30       ASG
#
#                     type_desc  player_id               player  \
# 0               Status Change   658668.0      Edward Olivares
# 1        Signed as Free Agent   658668.0      Edward Olivares
# 2                       Trade   669234.0  Justyn-Henry Malloy
# 3                       Trade        NaN                  NaN
# 4        Signed as Free Agent   686678.0        Chase Solesky
# 5               Status Change   686678.0        Chase Solesky
# 6         Claimed Off Waivers   691907.0      Tsung-Che Cheng
# 7               Status Change   666165.0          Blake Sabol
# 8        Signed as Free Agent   666165.0          Blake Sabol
# 9        Signed as Free Agent   657611.0             Cam Hill
# 10                      Trade   689172.0         Brett Wisely
# 11              Number Change   666018.0      Jonathan Aranda
# 12                      Trade   686610.0        Ken Waldichuk
# 13  Designated for Assignment   674370.0         Osvaldo Bido
# 14  Designated for Assignment   691907.0      Tsung-Che Cheng
# 15                      Trade        NaN                  NaN
# 16       Signed as Free Agent   837750.0     Brayan Rodriguez
# 17       Signed as Free Agent   837735.0     Deiverson Blanco
# 18       Signed as Free Agent   837967.0   Emmanuel Hernandez
# 19       Signed as Free Agent   837521.0      Fabricio Blanco
# 20       Signed as Free Agent   837970.0       Felipe Alcazar
# 21       Signed as Free Agent   837776.0    Gregory Rodriguez
# 22       Signed as Free Agent   822273.0         Jean Paredes
# 23       Signed as Free Agent   837837.0        Luis Almanzar
# 24       Signed as Free Agent   837973.0       Matias Palacio
# 25       Signed as Free Agent   825647.0         Raibel Reyes
# 26       Signed as Free Agent   836590.0        Victor Valdez
# 27                      Trade   805363.0          Chris Clark
# 28                      Trade   666158.0            Gavin Lux
# 29                      Trade   666139.0            Josh Lowe
# 30        Claimed Off Waivers   674370.0         Osvaldo Bido
# 31        Claimed Off Waivers   691907.0      Tsung-Che Cheng
# 32       Signed as Free Agent   592155.0           Cam Booser
# 33              Status Change   592155.0           Cam Booser
# 34                   Assigned   681806.0         Andrew Wantz
# 35                   Assigned   694391.0        Austin Vernon
# 36                   Assigned   694966.0       Brayden Taylor
# 37                   Assigned   811315.0        Brody Hopkins
# 38                   Assigned   695692.0        Cooper Kinney
# 39                   Assigned   699126.0      Gregory Barrios
# 40                   Assigned   700652.0          Kenny Piper
# 41                   Assigned   676831.0         Kodi Whitley
# 42                   Assigned   686482.0       Logan Driscoll
# 43                   Assigned   694312.0        Logan Workman
# 44                   Assigned   694375.0         T.J. Nichols
# 45                   Assigned   694420.0         Tatem Levins
# 46                   Assigned   691003.0          Tre' Morgan
# 47                   Assigned   694680.0        Trevor Martin
# 48                   Assigned   694494.0           Ty Johnson
# 49                   Assigned   800060.0         Xavier Isaac
#
#              from_team             to_team  \
# 0                  NaN      Tampa Bay Rays
# 1                  NaN      Tampa Bay Rays
# 2       Detroit Tigers      Tampa Bay Rays
# 3       Tampa Bay Rays      Detroit Tigers
# 4                  NaN      Tampa Bay Rays
# 5                  NaN      Tampa Bay Rays
# 6   Pittsburgh Pirates      Tampa Bay Rays
# 7                  NaN      Tampa Bay Rays
# 8                  NaN      Tampa Bay Rays
# 9                  NaN      Tampa Bay Rays
# 10      Atlanta Braves      Tampa Bay Rays
# 11                 NaN      Tampa Bay Rays
# 12      Atlanta Braves      Tampa Bay Rays
# 13                 NaN      Tampa Bay Rays
# 14                 NaN      Tampa Bay Rays
# 15      Tampa Bay Rays      Atlanta Braves
# 16                 NaN      Tampa Bay Rays
# 17                 NaN      Tampa Bay Rays
# 18                 NaN      Tampa Bay Rays
# 19                 NaN      Tampa Bay Rays
# 20                 NaN      Tampa Bay Rays
# 21                 NaN      Tampa Bay Rays
# 22                 NaN      Tampa Bay Rays
# 23                 NaN      Tampa Bay Rays
# 24                 NaN      Tampa Bay Rays
# 25                 NaN      Tampa Bay Rays
# 26                 NaN      Tampa Bay Rays
# 27  Los Angeles Angels      Tampa Bay Rays
# 28     Cincinnati Reds      Tampa Bay Rays
# 29      Tampa Bay Rays  Los Angeles Angels
# 30      Tampa Bay Rays       Miami Marlins
# 31      Tampa Bay Rays       New York Mets
# 32                 NaN      Tampa Bay Rays
# 33                 NaN      Tampa Bay Rays
# 34                 NaN      Tampa Bay Rays
# 35                 NaN      Tampa Bay Rays
# 36                 NaN      Tampa Bay Rays
# 37                 NaN      Tampa Bay Rays
# 38                 NaN      Tampa Bay Rays
# 39                 NaN      Tampa Bay Rays
# 40                 NaN      Tampa Bay Rays
# 41                 NaN      Tampa Bay Rays
# 42                 NaN      Tampa Bay Rays
# 43                 NaN      Tampa Bay Rays
# 44                 NaN      Tampa Bay Rays
# 45                 NaN      Tampa Bay Rays
# 46                 NaN      Tampa Bay Rays
# 47                 NaN      Tampa Bay Rays
# 48                 NaN      Tampa Bay Rays
# 49                 NaN      Tampa Bay Rays
#
#                                           description
# 0   RF Edward Olivares roster status changed by Ta...
# 1   Tampa Bay Rays signed free agent RF Edward Oli...
# 2   Detroit Tigers traded RF Justyn-Henry Malloy t...
# 3   Detroit Tigers traded RF Justyn-Henry Malloy t...
# 4   Tampa Bay Rays signed free agent RHP Chase Sol...
# 5   RHP Chase Solesky roster status changed by Tam...
# 6   Tampa Bay Rays claimed SS Tsung-Che Cheng off ...
# 7   C Blake Sabol roster status changed by Tampa B...
# 8   Tampa Bay Rays signed free agent C Blake Sabol...
# 9   Tampa Bay Rays signed free agent RHP Cam Hill ...
# 10  Atlanta Braves traded LHP Ken Waldichuk and 2B...
# 11            1B Jonathan Aranda changed number to 8.
# 12  Atlanta Braves traded LHP Ken Waldichuk and 2B...
# 13  Tampa Bay Rays designated RHP Osvaldo Bido for...
# 14  Tampa Bay Rays designated SS Tsung-Che Cheng f...
# 15  Atlanta Braves traded LHP Ken Waldichuk and 2B...
# 16  Tampa Bay Rays signed free agent SS Brayan Rod...
# 17  Tampa Bay Rays signed free agent LHP Deiverson...
# 18  Tampa Bay Rays signed free agent RHP Emmanuel ...
# 19  Tampa Bay Rays signed free agent SS Fabricio B...
# 20  Tampa Bay Rays signed free agent LHP Felipe Al...
# 21  Tampa Bay Rays signed free agent C Gregory Rod...
# 22  Tampa Bay Rays signed free agent OF Jean Pared...
# 23  Tampa Bay Rays signed free agent OF Luis Alman...
# 24  Tampa Bay Rays signed free agent SS Matias Pal...
# 25  Tampa Bay Rays signed free agent LHP Raibel Re...
# 26  Tampa Bay Rays signed free agent SS Victor Val...
# 27  Tampa Bay Rays traded RF Josh Lowe to Los Ange...
# 28  Tampa Bay Rays traded RF Josh Lowe to Los Ange...
# 29  Tampa Bay Rays traded RF Josh Lowe to Los Ange...
# 30  Miami Marlins claimed RHP Osvaldo Bido off wai...
# 31  New York Mets claimed SS Tsung-Che Cheng off w...
# 32  Tampa Bay Rays signed free agent LHP Cam Boose...
# 33  LHP Cam Booser roster status changed by Tampa ...
# 34  Tampa Bay Rays invited non-roster RHP Andrew W...
# 35  Tampa Bay Rays invited non-roster RHP Austin V...
# 36  Tampa Bay Rays invited non-roster 3B Brayden T...
# 37  Tampa Bay Rays invited non-roster RHP Brody Ho...
# 38  Tampa Bay Rays invited non-roster 2B Cooper Ki...
# 39  Tampa Bay Rays invited non-roster SS Gregory B...
# 40  Tampa Bay Rays invited non-roster C Kenny Pipe...
# 41  Tampa Bay Rays invited non-roster RHP Kodi Whi...
# 42  Tampa Bay Rays invited non-roster C Logan Dris...
# 43  Tampa Bay Rays invited non-roster RHP Logan Wo...
# 44  Tampa Bay Rays invited non-roster RHP T.J. Nic...
# 45  Tampa Bay Rays invited non-roster C Tatem Levi...
# 46  Tampa Bay Rays invited non-roster 1B Tre' Morg...
# 47  Tampa Bay Rays invited non-roster RHP Trevor M...
# 48  Tampa Bay Rays invited non-roster RHP Ty Johns...
# 49  Tampa Bay Rays invited non-roster 1B Xavier Is...

# %% [markdown]
# ## 10. Game Content (Highlights & Recap)

# %%
CONTENT_GAME_PK = 776918  # use a game_pk from df_schedule above

resp = requests.get(f"https://statsapi.mlb.com/api/v1/game/{CONTENT_GAME_PK}/content")
resp.raise_for_status()
content = resp.json()

# --- Recap article ---
recap = content.get("editorial", {}).get("recap", {}).get("mlb", {})
if recap:
    print("=== Recap ===")
    print(f"  Headline : {recap.get('headline')}")
    print(f"  Date     : {recap.get('date')}")
    print(f"  Blurb    : {recap.get('blurb')}")
    print()

# --- Highlights ---
items = content.get("highlights", {}).get("highlights", {}).get("items", [])

highlight_rows = []
for item in items:
    if item.get("type") != "video":
        continue
    playbacks = {p["name"]: p["url"] for p in item.get("playbacks", [])}
    highlight_rows.append({
        "id":          item.get("id"),
        "headline":    item.get("headline"),
        "description": item.get("description"),
        "duration":    item.get("duration"),
        "date":        item.get("date"),
        "mp4":         playbacks.get("mp4Avc"),
        "hls":         playbacks.get("hlsCloud"),
    })
    print(playbacks.get("hlsCloud"))

df_highlights = pd.DataFrame(highlight_rows)
print(f"=== Highlights ({len(df_highlights)} videos) ===")
df_highlights
# Out:
# === Recap ===
#   Headline : Freeman looking like old self as big as any Dodgers Deadline acquisition
#   Date     : 2025-08-02T04:25:00Z
#   Blurb    : TAMPA -- After nearly two months of frustration, Freddie Freeman is beginning to look much more like his normal self.
#
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/3f12b062-8f2269f9-5a238e9e-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/6701779d-d627a2d0-ede16ce5-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/187940cb-6870d206-2c965be4-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/d334f126-fd5bcb33-d536a8cd-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/20446d14-05ca8641-15b53836-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/59697802-dcde022d-476de63e-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/7993acea-d089e91c-5bd62f4c-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/e691fa37-4498afcc-c2a8f3c1-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/8ace336f-6513ce16-aff99a23-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/90243bdf-a8a8d917-a1eadeac-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/d91c4f3f-6154c4ec-66e4c3ea-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/753ca2d1-ab0fa629-60f99d81-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/0521480d-cbc425a3-a19504e6-csvm-diamondgcp-asset.m3u8
# https://mlb-cuts-diamond.mlb.com/FORGE/2025/2025-08/01/dedb23ab-91466f2f-2f85abc6-csvm-diamondgcp-asset.m3u8
# === Highlights (14 videos) ===
#                                                    id  \
# 0                    dodgers-vs-rays-highlights-x3049
# 1                        condensed-game-lad-tb-8-1-25
# 2   freddie-freeman-homers-12-on-a-fly-ball-to-rig...
# 3   freddie-freeman-doubles-28-on-a-sharp-line-dri...
# 4            shane-baz-in-play-run-s-to-alex-freeland
# 5                        shane-baz-s-eight-strikeouts
# 6           shane-baz-in-play-no-out-to-shohei-ohtani
# 7                  clayton-kershaw-s-three-strikeouts
# 8                        shane-baz-makes-a-sweet-snag
# 9             shane-baz-in-play-run-s-to-mookie-betts
# 10       nick-fortes-strikes-out-on-a-foul-tip-uxqcw7
# 11      josh-lowe-lines-out-to-left-fielder-alex-call
# 12  freddie-freeman-discusses-four-rbi-performance...
# 13                        kevin-cash-on-rays-5-0-loss
#
#                                              headline  \
# 0                         Dodgers vs. Rays Highlights
# 1                     Condensed Game: LAD@TB - 8/1/25
# 2                   Freddie Freeman's solo homer (12)
# 3                    Freddie Freeman's two-run double
# 4                    Alex Freeland's first career RBI
# 5                        Shane Baz's eight strikeouts
# 6            Shohei Ohtani singles after a broken bat
# 7                  Clayton Kershaw's three strikeouts
# 8                        Shane Baz makes a sweet snag
# 9                         Mookie Betts' sacrifice fly
# 10                    Clayton Kershaw K's Nick Fortes
# 11                    Justin Wrobleski earns the save
# 12  Freddie Freeman discusses four-RBI performance...
# 13                        Kevin Cash on Rays 5-0 loss
#
#                                           description  duration  \
# 0   Freddie Freeman and the Dodgers take on Shane ...  00:03:02
# 1   Condensed Game: Freddie Freeman and the Dodger...  00:08:46
# 2   Freddie Freeman hits a solo home run to right ...  00:00:22
# 3   Freddie Freeman doubles to right field in the ...  00:00:20
# 4   Alex Freeland singles to center field in the t...  00:00:15
# 5   Shane Baz tosses eight strikeouts through 5 in...  00:00:58
# 6   Shohei Ohtani singles on a ground ball to seco...  00:00:24
# 7   Clayton Kershaw tosses three strikeouts throug...  00:00:44
# 8   Shane Baz snags a line drive off Andy Pages' b...  00:00:16
# 9   Mookie Betts hits a sacrifice fly to left fiel...  00:00:16
# 10  Clayton Kershaw strikes out Nick Fortes with a...  00:00:07
# 11  Justin Wrobleski earns the save, forcing Josh ...  00:00:11
# 12  Freddie Freeman discusses his four-RBI perform...  00:00:45
# 13  Rays manager Kevin Cash discusses the clubs 5-...  00:01:03
#
#                         date  \
# 0    2025-08-02T03:53:32.17Z
# 1   2025-08-02T03:46:33.243Z
# 2   2025-08-02T00:53:13.706Z
# 3    2025-08-01T23:43:04.54Z
# 4   2025-08-02T00:38:38.597Z
# 5   2025-08-02T01:25:19.185Z
# 6   2025-08-02T00:15:48.999Z
# 7    2025-08-02T01:39:02.97Z
# 8   2025-08-01T23:48:19.904Z
# 9     2025-08-02T00:40:06.4Z
# 10  2025-08-02T00:10:41.019Z
# 11  2025-08-02T01:59:02.888Z
# 12  2025-08-02T03:23:45.543Z
# 13  2025-08-02T03:02:44.096Z
#
#                                                   mp4  \
# 0   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 1   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 2   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 3   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 4   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 5   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 6   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 7   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 8   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 9   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 10  https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 11  https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 12  https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 13  https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
#
#                                                   hls
# 0   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 1   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 2   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 3   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 4   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 5   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 6   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 7   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 8   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 9   https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 10  https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 11  https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 12  https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...
# 13  https://mlb-cuts-diamond.mlb.com/FORGE/2025/20...

# %%
print("=== Team Count Summary ===")
print(f"MLB teams:               {len(df_mlb)}")
print(f"Minor league teams:      {len(df_minor)}")
print()
print("Minor league breakdown:")
print(df_minor.groupby("level")["id"].count().rename("team_count").to_string())
# Out:
# === Team Count Summary ===
# MLB teams:               30
# Minor league teams:      30
#
# Minor league breakdown:
# level
# Triple-A    30
